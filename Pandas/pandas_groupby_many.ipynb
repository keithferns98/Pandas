# %%
import numpy as np
data=np.arange(5000).reshape(100,50)

# %%
data.shape
# Out:
# (100, 50)

# %%
import pandas as pd

# %%
col_name=['colum_'+str(i) for i in range(1,51)]

# %%
col_name
# Out:
# ['colum_1',
#  'colum_2',
#  'colum_3',
#  'colum_4',
#  'colum_5',
#  'colum_6',
#  'colum_7',
#  'colum_8',
#  'colum_9',
#  'colum_10',
#  'colum_11',
#  'colum_12',
#  'colum_13',
#  'colum_14',
#  'colum_15',
#  'colum_16',
#  'colum_17',
#  'colum_18',
#  'colum_19',
#  'colum_20',
#  'colum_21',
#  'colum_22',
#  'colum_23',
#  'colum_24',
#  'colum_25',
#  'colum_26',
#  'colum_27',
#  'colum_28',
#  'colum_29',
#  'colum_30',
#  'colum_31',
#  'colum_32',
#  'colum_33',
#  'colum_34',
#  'colum_35',
#  'colum_36',
#  'colum_37',
#  'colum_38',
#  'colum_39',
#  'colum_40',
#  'colum_41',
#  'colum_42',
#  'colum_43',
#  'colum_44',
#  'colum_45',
#  'colum_46',
#  'colum_47',
#  'colum_48',
#  'colum_49',
#  'colum_50']

# %%
dataf=pd.DataFrame(data,columns=col_name)

# %%
dataf
# Out:
#     colum_1  colum_2  colum_3  colum_4  colum_5  colum_6  colum_7  colum_8  \
# 0         0        1        2        3        4        5        6        7
# 1        50       51       52       53       54       55       56       57
# 2       100      101      102      103      104      105      106      107
# 3       150      151      152      153      154      155      156      157
# 4       200      201      202      203      204      205      206      207
# ..      ...      ...      ...      ...      ...      ...      ...      ...
# 95     4750     4751     4752     4753     4754     4755     4756     4757
# 96     4800     4801     4802     4803     4804     4805     4806     4807
# 97     4850     4851     4852     4853     4854     4855     4856     4857
# 98     4900     4901     4902     4903     4904     4905     4906     4907
# 99     4950     4951     4952     4953     4954     4955     4956     4957
#
# ...

# %%
type(dataf)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dataf['colum_1'])
# Out:
# pandas.core.series.Series

# %%
dict1={'name1': 'XYZ1','name2':'XYZ2'}
dict2={'score1': 15,'score2':15}

# %%
pd.DataFrame(data=[dict1,dict2])
# Out:
#   name1 name2  score1  score2
# 0  XYZ1  XYZ2     NaN     NaN
# 1   NaN   NaN    15.0    15.0

# %%
dict3={'name1':[range(10)],'name2':[range(10,20)]}

# %%
k=pd.DataFrame(dict3)

# %%
dfk=pd.read_csv('https://raw.githubusercontent.com/sharmasw/Data-Science-with-python/master/dataset_32_pendigits.csv')

# %%
dfk.head()
# Out:
#    input1  input2  input3  input4  input5  input6  input7  input8  input9  \
# 0      47     100      27      81      57      37      26       0       0
# 1       0      89      27     100      42      75      29      45      15
# 2       0      57      31      68      72      90     100     100      76
# 3       0     100       7      92       5      68      19      45      86
# 4       0      67      49      83     100     100      81      80      60
#
#    input10  input11  input12  input13  input14  input15  input16  class
# 0       23     56.0       53      100       90       40       98      8
# 1       15     37.0        0       69        2      100        6      2
# 2       75     50.0       51       28       25       16        0      1
# 3       34    100.0       45       74       23       67        0      4
# 4       60     40.0       40       33       20       47        0      1

# %%
dfk.columns
# Out:
# Index(['input1', 'input2', 'input3', 'input4', 'input5', 'input6', 'input7',
#        'input8', 'input9', 'input10', 'input11', 'input12', 'input13',
#        'input14', 'input15', 'input16', 'class'],
#       dtype='object')

# %%
dfk.dtypes
# Out:
# input1       int64
# input2       int64
# input3       int64
# input4       int64
# input5       int64
# input6       int64
# input7       int64
# input8       int64
# input9       int64
# input10      int64
# input11    float64
# input12      int64
# input13      int64
# input14      int64
# input15      int64
# input16      int64
# class        int64
# dtype: object

# %%
dfk.describe()
# Out:
#              input1        input2        input3        input4        input5  \
# count  10992.000000  10992.000000  10992.000000  10992.000000  10992.000000
# mean      38.814320     85.120269     40.605622     83.774199     49.770378
# std       34.257783     16.218571     26.342984     19.163646     34.100515
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000     76.000000     20.000000     72.000000     18.000000
# 50%       32.000000     89.000000     40.000000     91.000000     53.000000
# 75%       65.000000    100.000000     58.000000    100.000000     78.000000
# max      100.000000    100.000000    100.000000    100.000000    100.000000
#
#              input6        input7        input8        input9       input10  \
# count  10992.000000  10992.000000  10992.000000  10992.000000  10992.000000
# mean      65.573144     51.220251     44.498999     56.868541     33.695961
# ...

# %%
dfk.index
# Out:
# RangeIndex(start=0, stop=10992, step=1)

# %%
dfk.loc[1]
# Out:
# input1       0.0
# input2      89.0
# input3      27.0
# input4     100.0
# input5      42.0
# input6      75.0
# input7      29.0
# input8      45.0
# input9      15.0
# input10     15.0
# input11     37.0
# input12      0.0
# input13     69.0
# input14      2.0
# input15    100.0
# input16      6.0
# class        2.0
# Name: 1, dtype: float64

# %%
dfk.loc[[1]]
# Out:
#    input1  input2  input3  input4  input5  input6  input7  input8  input9  \
# 1       0      89      27     100      42      75      29      45      15
#
#    input10  input11  input12  input13  input14  input15  input16  class
# 1       15     37.0        0       69        2      100        6      2

# %%
dfk.loc[:3,['input1','input2']]
# Out:
#    input1  input2
# 0      47     100
# 1       0      89
# 2       0      57
# 3       0     100

# %%
dfk.loc[:4,['input1','input2','input3','input4']]
# Out:
#    input1  input2  input3  input4
# 0      47     100      27      81
# 1       0      89      27     100
# 2       0      57      31      68
# 3       0     100       7      92
# 4       0      67      49      83

# %%
dfk.iloc[1]
# Out:
# input1       0.0
# input2      89.0
# input3      27.0
# input4     100.0
# input5      42.0
# input6      75.0
# input7      29.0
# input8      45.0
# input9      15.0
# input10     15.0
# input11     37.0
# input12      0.0
# input13     69.0
# input14      2.0
# input15    100.0
# input16      6.0
# class        2.0
# Name: 1, dtype: float64

# %%
dfk.iloc[[1]]
# Out:
#    input1  input2  input3  input4  input5  input6  input7  input8  input9  \
# 1       0      89      27     100      42      75      29      45      15
#
#    input10  input11  input12  input13  input14  input15  input16  class
# 1       15     37.0        0       69        2      100        6      2

# %%
dfk.iloc[:4,:4]
# Out:
#    input1  input2  input3  input4
# 0      47     100      27      81
# 1       0      89      27     100
# 2       0      57      31      68
# 3       0     100       7      92

# %%
dfk[dfk['input2'].apply(lambda x :x<50)]
# Out:
#        input1  input2  input3  input4  input5  input6  input7  input8  input9  \
# 7           0      39       2      62      11       5      63       0     100
# 21          0      46      49      64      78      87     100     100      91
# 34          0       0      31      15      63      30      88      52     100
# 137         0      42      30      56      59      72      86      94     100
# 146         0      42      34      57      64      79      95     100     100
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 10805       0      43      32      58      67      79     100     100      89
# 10866       0      42      40      60      74      81     100     100      90
# 10879       0      45      42      70      66     100      60      62      47
# 10880       0       3      29      24      57      50      83      77     100
# 10933       0      15      29      40      59      68      85      97     100
#
# ...

# %%
dfk.isnull().sum()
# Out:
# input1       0
# input2       0
# input3       0
# input4       0
# input5       0
# input6       0
# input7       0
# input8       0
# input9       0
# input10      0
# input11    248
# input12      0
# input13      0
# input14      0
# input15      0
# input16      0
# class        0
# dtype: int64

# %%
dfk['input11'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10987    False
# 10988    False
# 10989    False
# 10990    False
# 10991    False
# Name: input11, Length: 10992, dtype: bool

# %%
dfk['input11']=dfk['input11'].fillna(dfk['input11'].mean())

# %%
dfk['input11'].isnull().sum()
# Out:
# 248

# %%
sample=pd.DataFrame(np.ones(10),columns=['column1'],index=['col'+str(i)for i in range(1,11)])

# %%
sample
# Out:
#        column1
# col1       1.0
# col2       1.0
# col3       1.0
# col4       1.0
# col5       1.0
# col6       1.0
# col7       1.0
# col8       1.0
# col9       1.0
# col10      1.0

# %%
np.cumsum(sample)
# Out:
#        column1
# col1       1.0
# col2       2.0
# col3       3.0
# col4       4.0
# col5       5.0
# col6       6.0
# col7       7.0
# col8       8.0
# col9       9.0
# col10     10.0

# %%
series_obj=dfk['input1']
padascore_DataFrame=dfk[['input1']]

# %%
series_obj.map(str)
# Out:
# 0        47
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 10987    36
# 10988    16
# 10989    56
# 10990    19
# 10991    38
# Name: input1, Length: 10992, dtype: object

# %%
series_obj[0].dtype
# Out:
# dtype('int64')

# %%
dictCheck={'a':10,'b':20,'c':30}

# %%
sampNumpy=np.array(['a','b','c','a','b','c'])

# %%
dataFSamp=pd.DataFrame(sampNumpy,columns=['ColumnName'])

# %%
dataFSamp
# Out:
#   ColumnName
# 0          a
# 1          b
# 2          c
# 3          a
# 4          b
# 5          c

# %%
dataFSamp['ColumnName'].map(dictCheck)
# Out:
# 0    10
# 1    20
# 2    30
# 3    10
# 4    20
# 5    30
# Name: ColumnName, dtype: int64

# %%
def checkfunc(x):
    return dictCheck[x]

# %%
d=dataFSamp['ColumnName'].map(checkfunc)

# %%
checkfunc('a')
# Out:
# 10

# %%
series_obj.dtype
# Out:
# dtype('int64')

# %%
def checkfunc(x):
    if x<10:
        return 'G10'
    elif x<50:
        return 'G50'
    elif x<90:
        return 'G90'
    else:
        return 'No'

# %%
dfk['input4'].apply(checkfunc)
# Out:
# 0        G90
# 1         No
# 2        G90
# 3         No
# 4        G90
#         ...
# 10987    G90
# 10988     No
# 10989    G90
# 10990    G90
# 10991    G90
# Name: input4, Length: 10992, dtype: object

# %%
import datetime
a=datetime.datetime.now()
dfk['input4'].apply(checkfunc)
b=datetime.datetime.now()
print(b-a)
# Out:
# 0:00:00.005985

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2021, 9, 26, 12, 33, 36, 831863)

# %%
import datetime
a=datetime.datetime.now()
dfk['input4'].map(checkfunc)
b=datetime.datetime.now()
print(b-a)
# Out:
# 0:00:00.004986

# %%
import datetime
a=datetime.datetime.now()
dfk['input4'].apply(lambda x:checkfunc(x))
b=datetime.datetime.now()
print(b-a)
# Out:
# 0:00:00.007980

# %%
#apply map

# %%
dfk.applymap(checkfunc)
# Out:
#       input1 input2 input3 input4 input5 input6 input7 input8 input9 input10  \
# 0        G50     No    G50    G90    G90    G50    G50    G10    G10     G50
# 1        G10    G90    G50     No    G50    G90    G50    G50    G50     G50
# 2        G10    G90    G50    G90    G90     No     No     No    G90     G90
# 3        G10     No    G10     No    G10    G90    G50    G50    G90     G50
# 4        G10    G90    G50    G90     No     No    G90    G90    G90     G90
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 10987    G50     No    G50    G90    G10    G50    G50    G50     No     G50
# 10988    G50    G90    G50     No    G90    G90    G50    G50    G10     G10
# 10989    G90     No    G50    G90    G10    G50    G50    G10    G90     G50
# 10990    G50     No    G10    G90    G10    G50    G50    G10     No     G50
# 10991    G50     No    G50    G90    G50    G90    G10    G50    G90     G50
#
# ...

# %%
def ok(x,y):
    try:
        return (x/y)
    except:
        return 0

# %%
dfk[['input2','input3']].apply(lambda x:ok(*x),axis=1)
# Out:
# 0         3.703704
# 1         3.296296
# 2         1.838710
# 3        14.285714
# 4         1.367347
#            ...
# 10987     4.166667
# 10988     1.829268
# 10989     3.703704
# 10990     0.000000
# 10991     2.702703
# Length: 10992, dtype: float64

# %%
table1=pd.DataFrame(data={'column1':[1,2,3,4],'column2':[5,6,7,8]})
table2=pd.DataFrame(data={'column1':[9,10,11,12],'column2':[13,14,15,16]})
table3=pd.DataFrame(data={'column3':[1,1,2,2],'column4':[5,6,7,8]})

# %%
pd.concat([table1,table2])
# Out:
#    column1  column2
# 0        1        5
# 1        2        6
# 2        3        7
# 3        4        8
# 0        9       13
# 1       10       14
# 2       11       15
# 3       12       16

# %%
pd.concat([table1,table3])
# Out:
#    column1  column2  column3  column4
# 0      1.0      5.0      NaN      NaN
# 1      2.0      6.0      NaN      NaN
# 2      3.0      7.0      NaN      NaN
# 3      4.0      8.0      NaN      NaN
# 0      NaN      NaN      1.0      5.0
# 1      NaN      NaN      1.0      6.0
# 2      NaN      NaN      2.0      7.0
# 3      NaN      NaN      2.0      8.0

# %%
pd.merge(table1,table3,left_on=['column1'],right_on=['column3'],how='left')
# Out:
#    column1  column2  column3  column4
# 0        1        5      1.0      5.0
# 1        1        5      1.0      6.0
# 2        2        6      2.0      7.0
# 3        2        6      2.0      8.0
# 4        3        7      NaN      NaN
# 5        4        8      NaN      NaN

# %%
dexcel=pd.read_excel(r'C:\Users\keith\Downloads\Sample - Superstore.xls')

# %%
# !pip install xlrd

# %%
dexcel.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
dexcel.shape
# Out:
# (9994, 21)

# %%
dexcel.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
dexcel.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
np.unique(dexcel['Product ID'])
# Out:
# array(['FUR-BO-10000112', 'FUR-BO-10000330', 'FUR-BO-10000362', ...,
#        'TEC-PH-10004924', 'TEC-PH-10004959', 'TEC-PH-10004977'],
#       dtype=object)

# %%
len(np.unique(dexcel['Product ID']))
# Out:
# 1862

# %%
for col in dexcel.columns:
    print(col,'>>>>',len(np.unique(dexcel[col])))
# Out:
# Row ID >>>> 9994
# Order ID >>>> 5009
# Order Date >>>> 1237
# Ship Date >>>> 1334
# Ship Mode >>>> 4
# Customer ID >>>> 793
# Customer Name >>>> 793
# Segment >>>> 3
# Country >>>> 1
# City >>>> 531
# State >>>> 49
# Postal Code >>>> 631
# Region >>>> 4
# Product ID >>>> 1862
# Category >>>> 3
# Sub-Category >>>> 17
# Product Name >>>> 1850
# Sales >>>> 6144
# Quantity >>>> 14
# Discount >>>> 12
# Profit >>>> 7545

# %%
mean=pd.pivot_table(dexcel,index="Sub-Category",values=['Sales','Profit'],aggfunc='mean').reset_index()

# %%
pd.pivot_table(dexcel,index='Sub-Category',values=['Sales','Profit'],aggfunc=np.max)
# Out:
#                  Profit      Sales
# Sub-Category
# Accessories    829.3754   3347.370
# Appliances     793.7160   2625.120
# Art            112.5740   1113.024
# Binders       4946.3700   9892.740
# Bookcases     1013.1270   4404.900
# Chairs         770.3520   4416.174
# Copiers       8399.9760  17499.950
# Envelopes      204.0714    604.656
# Fasteners       21.8880     93.360
# Furnishings    387.5676   1336.440
# Labels         385.3752    786.480
# Machines      2799.9840  22638.480
# Paper          352.2960    733.950
# Phones        1228.1787   4548.810
# Storage        792.2691   2934.330
# Supplies       327.5060   8187.650
# Tables         629.0100   4297.644

# %%
std=pd.pivot_table(dexcel,index='Sub-Category',values=['Sales','Profit'],aggfunc='std').reset_index()

# %%
mean.columns=['Sub-Category','mean_profit','mean_sales']
std.columns=['Sub-Category','std_profit','std-sales']

# %%
merge=pd.merge(mean,std,on='Sub-Category',how='left')

# %%
merge
# Out:
#    Sub-Category  mean_profit   mean_sales   std_profit    std-sales
# 0   Accessories    54.111788   215.974604   106.155455   334.965015
# 1    Appliances    38.922758   230.755710   148.319146   388.949643
# 2           Art     8.200737    34.068834    13.384264    60.122465
# 3       Binders    19.843574   133.560560   306.196773   563.251188
# 4     Bookcases   -15.230509   503.859633   182.034224   638.748523
# 5        Chairs    43.095894   532.332420   127.099922   550.148243
# 6       Copiers   817.909190  2198.941618  1460.921156  3175.665867
# 7     Envelopes    27.418019    64.867724    35.354983    84.351633
# 8     Fasteners     4.375660    13.936774     5.055053    12.416593
# 9   Furnishings    13.645918    95.825668    52.753228   147.893640
# 10       Labels    15.236962    34.303055    34.084127    74.119287
# 11     Machines    29.432669  1645.553313  1099.070067  2765.102088
# 12        Paper    24.856620    57.284092    35.225214    78.167639
# ...

# %%
dfk.head()
# Out:
#    input1  input2  input3  input4  input5  input6  input7  input8  input9  \
# 0      47     100      27      81      57      37      26       0       0
# 1       0      89      27     100      42      75      29      45      15
# 2       0      57      31      68      72      90     100     100      76
# 3       0     100       7      92       5      68      19      45      86
# 4       0      67      49      83     100     100      81      80      60
#
#    input10  input11  input12  input13  input14  input15  input16  class
# 0       23     56.0       53      100       90       40       98      8
# 1       15     37.0        0       69        2      100        6      2
# 2       75     50.0       51       28       25       16        0      1
# 3       34    100.0       45       74       23       67        0      4
# 4       60     40.0       40       33       20       47        0      1

# %%
dexcel.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
custName=pd.pivot_table(dexcel,index=['Customer ID'],values=['Sales'],aggfunc='sum')\
         .reset_index().sort_values(by='Sales',ascending=False).head(20)['Customer ID'].values

# %%
custName
# Out:
# array(['SM-20320', 'TC-20980', 'RB-19360', 'TA-21385', 'AB-10105',
#        'KL-16645', 'SC-20095', 'HL-15040', 'SE-20110', 'CC-12370',
#        'TS-21370', 'GT-14710', 'BM-11140', 'SV-20365', 'CJ-12010',
#        'CL-12565', 'ME-17320', 'KF-16285', 'BS-11365', 'EH-13765'],
#       dtype=object)

# %%
custName['Customer ID'].values
# Out:
# array(['SM-20320', 'TC-20980', 'RB-19360', 'TA-21385', 'AB-10105',
#        'KL-16645', 'SC-20095', 'HL-15040', 'SE-20110', 'CC-12370',
#        'TS-21370', 'GT-14710', 'BM-11140', 'SV-20365', 'CJ-12010',
#        'CL-12565', 'ME-17320', 'KF-16285', 'BS-11365', 'EH-13765'],
#       dtype=object)

# %%
np.unique(dexcel['Region'])
# Out:
# array(['Central', 'East', 'South', 'West'], dtype=object)

# %%
filtData=dexcel[(dexcel['Customer ID'].isin(custName)) & (dexcel['Region']=='South')]

# %%
filtData
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1121    1122  US-2014-147627 2014-01-20 2014-01-26  Standard Class
# 1122    1123  US-2014-147627 2014-01-20 2014-01-26  Standard Class
# 1123    1124  US-2014-147627 2014-01-20 2014-01-26  Standard Class
# 1124    1125  US-2014-147627 2014-01-20 2014-01-26  Standard Class
# 1125    1126  US-2014-147627 2014-01-20 2014-01-26  Standard Class
# 1126    1127  US-2014-147627 2014-01-20 2014-01-26  Standard Class
# 1455    1456  CA-2017-148474 2017-06-12 2017-06-19  Standard Class
# 1456    1457  CA-2017-148474 2017-06-12 2017-06-19  Standard Class
# 1564    1565  CA-2014-116239 2014-03-04 2014-03-04        Same Day
# 1932    1933  CA-2017-161200 2017-08-06 2017-08-10    Second Class
# 1933    1934  CA-2017-161200 2017-08-06 2017-08-10    Second Class
# 2266    2267  CA-2017-149146 2017-10-12 2017-10-12        Same Day
# 2551    2552  CA-2017-101042 2017-11-19 2017-11-23  Standard Class
# ...

# %%
dexcel[dexcel['Customer ID'].isin(custName)]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 111      112  CA-2016-128867 2016-11-03 2016-11-10  Standard Class
# 112      113  CA-2016-128867 2016-11-03 2016-11-10  Standard Class
# 164      165  CA-2014-139892 2014-09-08 2014-09-12  Standard Class
# 165      166  CA-2014-139892 2014-09-08 2014-09-12  Standard Class
# 166      167  CA-2014-139892 2014-09-08 2014-09-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 9849    9850  CA-2014-142979 2014-04-12 2014-04-18  Standard Class
# 9850    9851  CA-2016-158155 2016-05-02 2016-05-06  Standard Class
# 9851    9852  CA-2016-158155 2016-05-02 2016-05-06  Standard Class
# 9852    9853  CA-2016-158155 2016-05-02 2016-05-06  Standard Class
# 9853    9854  CA-2016-158155 2016-05-02 2016-05-06  Standard Class
#
#      Customer ID Customer Name    Segment        Country           City  ...  \
# 111     CL-12565   Clay Ludtke   Consumer  United States      Urbandale  ...
# ...

# %%
dexcel.groupby('Region').sum()
# Out:
#            Row ID  Postal Code        Sales  Quantity  Discount       Profit
# Region
# Central  11685963    151786150  501239.8908      8780    558.34   39706.3625
# East     14073919     50171698  678781.2400     10618    414.00   91522.7800
# South     8213295     55875052  391721.9050      6209    238.55   46749.4303
# West     15971838    293739752  725457.8245     12266    350.20  108418.4489

# %%
dexcel.groupby(['Region','Customer ID']).sum().head(5)
# Out:
#                      Row ID  Postal Code     Sales  Quantity  Discount  \
# Region  Customer ID
# Central AA-10315      23123       425470  4780.552        19       0.8
#         AA-10375       1617       136208   178.370         5       0.0
#         AA-10480      54075       570205  1747.500        31       0.0
#         AA-10645      24027       219360  1971.460        12       0.0
#         AB-10015      25828       222257   576.564         6       0.2
#
#                        Profit
# Region  Customer ID
# Central AA-10315    -650.5971
#         AA-10375      62.0658
#         AA-10480     420.4986
#         AA-10645     439.3138
#         AB-10015     114.3432

# %%
dexcel.groupby(['Region','Customer ID']).agg({'Sales':'sum','Profit':'sum'})\
.reset_index()
# Out:
#        Region Customer ID     Sales     Profit
# 0     Central    AA-10315  4780.552  -650.5971
# 1     Central    AA-10375   178.370    62.0658
# 2     Central    AA-10480  1747.500   420.4986
# 3     Central    AA-10645  1971.460   439.3138
# 4     Central    AB-10015   576.564   114.3432
# ...       ...         ...       ...        ...
# 2496     West    XP-21865   660.190   298.3414
# 2497     West    YC-21895  1215.676   382.0575
# 2498     West    YS-21880  5754.172  1551.5945
# 2499     West    ZC-21910  2641.089   346.0942
# 2500     West    ZD-21925   306.200    42.4662
#
# [2501 rows x 4 columns]

# %%
saveForExample=dexcel.groupby(['Region','Customer ID']).agg({'Sales':'sum','Profit':'sum'}).reset_index()

# %%
saveForExample
# Out:
#        Region Customer ID     Sales     Profit
# 0     Central    AA-10315  3930.072  -650.5971
# 1     Central    AA-10375   149.970    62.0658
# 2     Central    AA-10480   479.970   420.4986
# 3     Central    AA-10645  1323.900   439.3138
# 4     Central    AB-10015   341.960   114.3432
# ...       ...         ...       ...        ...
# 2496     West    XP-21865   314.550   298.3414
# 2497     West    YC-21895  1199.976   382.0575
# 2498     West    YS-21880  2793.528  1551.5945
# 2499     West    ZC-21910  1298.550   346.0942
# 2500     West    ZD-21925   213.480    42.4662
#
# [2501 rows x 4 columns]

# %%
[''.join(i) for i in saveForExample.columns]
# Out:
# ['Region', 'Customer ID', 'Sales', 'Profit']

# %%
saveForExample['profitRatio']=saveForExample['Profit']/saveForExample['Sales']

# %%
saveForExample.head()
# Out:
#     Region Customer ID     Sales    Profit  profitRatio
# 0  Central    AA-10315  4780.552 -650.5971    -0.136092
# 1  Central    AA-10375   178.370   62.0658     0.347961
# 2  Central    AA-10480  1747.500  420.4986     0.240629
# 3  Central    AA-10645  1971.460  439.3138     0.222837
# 4  Central    AB-10015   576.564  114.3432     0.198318

# %%
saveForExample=saveForExample.sort_values(['Region','profitRatio'],ascending=False)

# %%
saveForExample.head()
# Out:
#      Region Customer ID   Sales   Profit  profitRatio
# 2367   West    RD-19810  146.82  73.4100         0.50
# 2206   West    LB-16735   21.48  10.7400         0.50
# 2422   West    SM-20320    9.96   4.8804         0.49
# 1939   West    CG-12040   11.76   5.7624         0.49
# 2468   West    TP-21415   12.96   6.3504         0.49

# %%
saveForExample.nlargest(20,'Sales')
# Out:
#        Region Customer ID      Sales     Profit  profitRatio
# 1754    South    SM-20320  23669.196 -1787.0435    -0.075501
# 588   Central    TC-20980  18437.138  8745.0635     0.474318
# 2354     West    RB-19360  14345.276  6807.0879     0.474518
# 1250     East    TA-21385  13723.498  4599.2073     0.335134
# 6     Central    AB-10105  12181.594  5362.6135     0.440223
# 68    Central    BM-11140  10539.896 -1878.7892    -0.178255
# 909      East    HL-15040  10522.550  5045.8564     0.479528
# 718      East    BS-11365  10022.293  2558.5802     0.255289
# 527   Central    SC-20095   9900.190  4668.6935     0.471576
# 896      East    GT-14710   9382.934  1749.1070     0.186414
# 1241     East    SV-20365   9216.568  1356.8781     0.147222
# 1744    South    SE-20110   8805.040  2825.2862     0.320871
# 743      East    CC-12370   8765.660  1190.5972     0.135825
# 2193     West    KL-16645   8472.394   426.6132     0.050353
# ...

# %%
saveForExample.nlargest(20,'profitRatio')
# Out:
#        Region Customer ID   Sales    Profit  profitRatio
# 2367     West    RD-19810  146.82   73.4100     0.500000
# 2206     West    LB-16735   21.48   10.7400     0.500000
# 1319    South    AG-10765  113.10   56.5500     0.500000
# 950      East    JK-15325   23.36   11.6800     0.500000
# 778      East    CS-12175  196.21   98.1050     0.500000
# 1157     East    RA-19915   48.94   24.4700     0.500000
# 1016     East    LC-16930    8.40    4.2000     0.500000
# 204   Central    EC-14050   38.16   19.0800     0.500000
# 1652    South    MS-17770   37.44   18.5640     0.495833
# 858      East    EL-13735   37.66   18.4534     0.490000
# 238   Central    GB-14575  279.90  137.1510     0.490000
# 2422     West    SM-20320    9.96    4.8804     0.490000
# 1469    South    EJ-14155   48.69   23.8581     0.490000
# 1051     East    MC-17845    6.03    2.9547     0.490000
# 1939     West    CG-12040   11.76    5.7624     0.490000
# ...

# %%
saveForExample.groupby(['Region']).agg({'profitRatio':{lambda x:x.nlargest(20).mean()}})
# Out:
#         profitRatio
#            <lambda>
# Region
# Central    0.479799
# East       0.484697
# South      0.481304
# West       0.482885

# %%
saveForExample[saveForExample['Region']=='West'].head(20)['profitRatio'].mean()
# Out:
# 0.48288526990598823

# %%
#Stacking

# %%
sampstackdata=saveForExample.head()

# %%
sampstackdata
# Out:
#      Region Customer ID   Sales   Profit  profitRatio
# 2367   West    RD-19810  146.82  73.4100         0.50
# 2206   West    LB-16735   21.48  10.7400         0.50
# 2422   West    SM-20320    9.96   4.8804         0.49
# 1939   West    CG-12040   11.76   5.7624         0.49
# 2468   West    TP-21415   12.96   6.3504         0.49

# %%
sampstackdata.stack()
# Out:
# 2367  Region             West
#       Customer ID    RD-19810
#       Sales            146.82
#       Profit            73.41
#       profitRatio         0.5
# 2206  Region             West
#       Customer ID    LB-16735
#       Sales             21.48
#       Profit            10.74
#       profitRatio         0.5
# 2422  Region             West
#       Customer ID    SM-20320
#       Sales              9.96
#       Profit           4.8804
#       profitRatio        0.49
# 1939  Region             West
#       Customer ID    CG-12040
#       Sales             11.76
#       Profit           5.7624
#       profitRatio        0.49
# 2468  Region             West
#       Customer ID    TP-21415
#       Sales             12.96
#       Profit           6.3504
#       profitRatio        0.49
# dtype: object
